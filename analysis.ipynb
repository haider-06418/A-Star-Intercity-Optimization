# %% [markdown]
# # Analysis

# %%
import json
import time
import matplotlib.pyplot as plt

import a_star
import dijkstra
import bestfs

# %%
# function to load json file into a dictionary
def load_json(json_file):
    with open(json_file, 'r') as file:
        data = json.load(file)
    return data


# plotting a bar chart
def plot_bar_chart(categories, values, title, ylabel):
    # plt.figure(figsize=(10, 6))
    plt.figure(figsize=(8, 6))
    plt.bar(categories, values, color='skyblue')
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xticks(categories)
    plt.show()

# %%
graph_file = "graphs/graph_updated.json"
graph = load_json(graph_file)

# %%
# measuring performance metrics of for all algorithms for the given start and end nodes

def main(graph, start_city, goal_city):

    algorithms = ['A*', 'Dijkstra', 'BestFS']
    times = []
    path_costs = []
    nodes_explored = []
    paths = []

    # a star
    start_time = time.time()
    path_1, cost_1, no_of_nodes_explored  = a_star.a_star_search(graph, start_city, goal_city) 
    end_time = time.time()
    time_taken = end_time - start_time
    times.append(time_taken)
    path_costs.append(cost_1)
    nodes_explored.append(no_of_nodes_explored)
    paths.append(path_1)
    print('A*:')
    if path_1:
        print(f"Optimal Path from {start_city} to {goal_city}:")
        print(" -> ".join(path_1))
        print(f"Total Cost: {cost_1}")
        print(f"Number of nodes explored: {no_of_nodes_explored}")
        print(f"Time taken: {time_taken} seconds")
    else:
        print(f"No path found from {start_city} to {goal_city}.")
    print(' ')


    # djkistra 
    start_time = time.time()
    path_2, cost_2, no_of_nodes_explored = dijkstra.dijkstra_algorithm(graph, start_city, goal_city)
    end_time = time.time() 
    time_taken = end_time - start_time
    times.append(time_taken)
    path_costs.append(cost_2)
    nodes_explored.append(no_of_nodes_explored)
    paths.append(path_2)
    print('Dijkstra:')
    if path_2:
        print(f"Optimal Path from {start_city} to {goal_city}:")
        print(" -> ".join(path_2))
        print(f"Total Cost: {cost_2}")
        print(f"Number of nodes explored: {no_of_nodes_explored}")
        print(f"Time taken: {time_taken} seconds")
    else:
        print(f"No path found from {start_city} to {goal_city}.")
    print(' ')



    # best first search
    start_time = time.time()
    path_3, cost_3, no_of_nodes_explored = bestfs.best_first_search(graph, start_city, goal_city)
    end_time = time.time()
    time_taken = end_time - start_time
    times.append(time_taken)
    path_costs.append(cost_3)
    nodes_explored.append(no_of_nodes_explored)
    paths.append(path_3)
    print('BestFS:')
    if path_3:
        print(f"Optimal Path from {start_city} to {goal_city}:")
        print(" -> ".join(path_3))
        print(f"Total Cost: {cost_3}")
        print(f"Number of nodes explored: {no_of_nodes_explored}")
        print(f"Time taken: {time_taken} seconds")
    else:
        print(f"No path found from {start_city} to {goal_city}.")
    print(' ')


    # plotting each metric
    plot_bar_chart(algorithms, times, 'Execution Time Comparison', 'Time (seconds)')
    plot_bar_chart(algorithms, path_costs, 'Path Cost Comparison', 'Cost')
    plot_bar_chart(algorithms, nodes_explored, 'Nodes Explored Comparison', 'Number of Nodes')

# %%
start_city = "Karachi"
goal_city = "Islamabad"

# %%
main(graph, start_city, goal_city)
# Out:
# A*:
# Optimal Path from Karachi to Islamabad:
# Karachi -> Jamshoro -> Nawabshah -> Khairpur -> Ghotki -> Khanpur -> Lodhran -> Khanewal -> Toba Tek Singh -> Chiniot -> Mandi Bahauddin -> Islamabad
# Total Cost: 1257.1589715807343
# Number of nodes explored: 95
# Time taken: 0.001220703125 seconds
#
# Dijkstra:
# Optimal Path from Karachi to Islamabad:
# Karachi -> Jamshoro -> Nawabshah -> Khairpur -> Ghotki -> Khanpur -> Lodhran -> Khanewal -> Toba Tek Singh -> Chiniot -> Mandi Bahauddin -> Islamabad
# Total Cost: 1257.1589715807343
# Number of nodes explored: 103
# Time taken: 0.0008549690246582031 seconds
#
# BestFS:
# Optimal Path from Karachi to Islamabad:
# Karachi -> Islamabad
# Total Cost: 1359.1451298592262
# Number of nodes explored: 29
# Time taken: 0.00043511390686035156 seconds

# %%
start_city = "Jhelum"
goal_city = "Gwadar"

main(graph, start_city, goal_city)
# Out:
# A*:
# Optimal Path from Jhelum to Gwadar:
# Jhelum -> Mandi Bahauddin -> Chiniot -> Toba Tek Singh -> Vihari -> Turbat -> Gwadar
# Total Cost: 474.186351223977
# Number of nodes explored: 75
# Time taken: 0.0008528232574462891 seconds
#
# Dijkstra:
# Optimal Path from Jhelum to Gwadar:
# Jhelum -> Mandi Bahauddin -> Chiniot -> Toba Tek Singh -> Vihari -> Turbat -> Gwadar
# Total Cost: 474.186351223977
# Number of nodes explored: 80
# Time taken: 0.0005772113800048828 seconds
#
# BestFS:
# Optimal Path from Jhelum to Gwadar:
# Jhelum -> Gwadar
# Total Cost: 531.2477575465906
# Number of nodes explored: 83
# Time taken: 0.0006651878356933594 seconds

# %%
start_city = "Karachi"
goal_city = "Muzaffarabad"

main(graph, start_city, goal_city)
# Out:
# A*:
# Optimal Path from Karachi to Muzaffarabad:
# Karachi -> Jamshoro -> Nawabshah -> Khairpur -> Ghotki -> Khanpur -> Lodhran -> Khanewal -> Toba Tek Singh -> Chiniot -> Mandi Bahauddin -> Rawalpindi -> Muzaffarabad
# Total Cost: 1340.989180533112
# Number of nodes explored: 103
# Time taken: 0.0012507438659667969 seconds
#
# Dijkstra:
# Optimal Path from Karachi to Muzaffarabad:
# Karachi -> Jamshoro -> Nawabshah -> Khairpur -> Ghotki -> Khanpur -> Lodhran -> Khanewal -> Toba Tek Singh -> Chiniot -> Mandi Bahauddin -> Rawalpindi -> Muzaffarabad
# Total Cost: 1340.989180533112
# Number of nodes explored: 110
# Time taken: 0.0008990764617919922 seconds
#
# BestFS:
# Optimal Path from Karachi to Muzaffarabad:
# Karachi -> Muzaffarabad
# Total Cost: 1421.7488170270524
# Number of nodes explored: 47
# Time taken: 0.0005290508270263672 seconds
